# %%
#https://stackoverflow.com/questions/48376580/google-colab-how-to-read-data-from-my-google-drive
#https://colab.research.google.com/drive/1srw_HFWQ2SMgmWIawucXfusGzrj1_U0q#scrollTo=c99EvWo1s9-x

# Load the Drive helper and mount
from google.colab import drive

# %%
# This will prompt for authorization.
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
matplotlib.get_backend()
# Out:
# 'module://ipykernel.pylab.backend_inline'

# %%
import os
from PIL import Image
from matplotlib import pyplot as plt
from matplotlib import gridspec
#plt.switch_backend('TkAgg')

# %%
im = Image.open('/content/drive/My Drive/100NIKON/DSCN3582.JPG')

# %%
os.getcwd()
# Out:
# '/content'

# %%
# Out:
# drive/  sample_data/

# %%
print(im.format, im.size, im.mode)
# Out:
# JPEG (2592, 1944) RGB

# %%
#hace una copia de la imagen en .bmp y la manda a paint para visualizar
im.show()

# %%
from IPython.display import Image

# %%
Image('/content/drive/My Drive/100NIKON/DSCN3585.JPG', width=400, height=400)

# %%
#RGB to gray scale
im_gray = im.convert('L')
im_hist_gray = im_gray.histogram()
plt.hist(im_hist_gray)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-6986062e1442> in <module>()
# ----> 1 im_gray = im.convert('L')
#       2 im_hist_gray = im_gray.histogram()
#       3 plt.hist(im_hist_gray)
#       4 plt.show()
#
# NameError: name 'im' is not defined

# %%
#Valor RGB para un pixel específico
im.getpixel((0,0))
# Out:
# (109, 85, 59)

# %%
#mezclo los canales r,g,b -> b,g,r
r, g, b = im.split()
#im_invert = Image.merge("RGB", (b, g, r))
#im_invert.show()

# %%
plt.close()
im_r_hist = r.histogram()
im_g_hist = g.histogram()
im_b_hist = b.histogram()
im_rgb_hist = im.histogram()
plt.hist(im_r_hist)
plt.hist(im_g_hist)
plt.hist(im_b_hist)
#plt.hist((im_r_hist, im_g_hist, im_b_hist)) #bars side by side no stacked
plt.show()

# %%
plt.close()


fig = plt.figure(figsize=(10,5))

fig.suptitle('Histograma RGB', fontsize=18, y=1.05, horizontalalignment='center')

ax1 = fig.add_subplot(331) #fila columna orden
ax1.plot(im_r_hist, color='red')
plt.title('Red Channel')
ax2 = fig.add_subplot(332)
ax2.plot(im_g_hist, color='green')
plt.title('Green Channel')
ax3 = fig.add_subplot(333)
ax3.plot(im_b_hist, color='blue')
plt.title('Blue Channel')

gs = gridspec.GridSpec(3, 3)

ax4 = fig.add_subplot(gs[1,:3])
ax4.plot(im_rgb_hist, color='black')
plt.title('RGB')

ax5 = fig.add_subplot(gs[2,:3])
ax5.plot(im_hist_gray, color='gray')
plt.title('Gray Scale')

fig.tight_layout()

#plt.subplot(211)
#plt.plot(im_r_hist, im_g_hist)
#plt.plot(im_r_hist, color = 'red')
#plt.plot(im_g_hist, color = 'green')
#plt.plot(im_b_hist, color = 'blue')
#plt.plot(im_hist_gray, color = 'gray')
plt.show()

# %%
plt.close()
fig, ax = plt.subplots(4, figsize=(6, 12))
ax[0].hist(im_r_hist, color = 'red')
ax[1].hist(im_g_hist, color = 'green')
ax[2].hist(im_b_hist, color = 'blue')
ax[3].hist(im_hist_gray, color = 'gray')
#fig.show()
fig.suptitle('Histograma RGB', fontsize=18, y=1.03)
fig.tight_layout()
fig.savefig("prueba.png")
plt.show()

# %%
import numpy as np

# %%
import cv2
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: module compiled against API version 0xb but this version of numpy is 0xa
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-43-72fbbcfe2587> in <module>()
# ----> 1 import cv2
#
# ImportError: numpy.core.multiarray failed to import
